# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import GaussianNB,MultinomialNB
import warnings
warnings.filterwarnings('ignore')

# %%
salary_train=pd.read_csv('SalaryData_Train.csv')
salary_train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
salary_test=pd.read_csv('SalaryData_Test.csv')
salary_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %% [markdown]
# ### EDA:

# %%
salary_train.shape,salary_test.shape
# Out:
# ((30161, 14), (15060, 14))

# %%
salary_train.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_test.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_train.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
salary_test.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
sns.countplot(salary_train['Salary'])
plt.show()

# %%
sns.countplot(salary_test['Salary'])
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
le=LabelEncoder()

# %%
labeling_features=salary_train.columns
labeling_features=labeling_features.drop(['age','educationno','capitalgain','capitalloss','hoursperweek'])

# %%
for i in labeling_features:
    salary_train[i]=le.fit_transform(salary_train[i])
salary_train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
for i in labeling_features:
    salary_test[i]=le.fit_transform(salary_test[i])
salary_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
#Standardize the data
#Training data
scaler=MinMaxScaler()
salary_train_scaled=scaler.fit_transform(salary_train)
salary_train_scaled=pd.DataFrame(salary_train_scaled,columns=salary_train.columns)
salary_train_scaled
# Out:
#             age  workclass  education  educationno  maritalstatus  occupation  \
# 0      0.301370   0.833333   0.600000     0.800000       0.666667    0.000000
# 1      0.452055   0.666667   0.600000     0.800000       0.333333    0.230769
# 2      0.287671   0.333333   0.733333     0.533333       0.000000    0.384615
# 3      0.493151   0.333333   0.066667     0.400000       0.333333    0.384615
# 4      0.150685   0.333333   0.600000     0.800000       0.333333    0.692308
# ...         ...        ...        ...          ...            ...         ...
# 30156  0.136986   0.333333   0.466667     0.733333       0.333333    0.923077
# 30157  0.315068   0.333333   0.733333     0.533333       0.333333    0.461538
# 30158  0.561644   0.333333   0.733333     0.533333       1.000000    0.000000
# 30159  0.068493   0.333333   0.733333     0.533333       0.666667    0.000000
# 30160  0.479452   0.500000   0.733333     0.533333       0.333333    0.230769
#
# ...

# %%
#Testing Data
salary_test_scaled=scaler.fit_transform(salary_test)
salary_test_scaled=pd.DataFrame(salary_test_scaled,columns=salary_test.columns)
salary_test_scaled
# Out:
#             age  workclass  education  educationno  maritalstatus  occupation  \
# 0      0.109589   0.333333   0.066667     0.400000       0.666667    0.461538
# 1      0.287671   0.333333   0.733333     0.533333       0.333333    0.307692
# 2      0.150685   0.166667   0.466667     0.733333       0.333333    0.769231
# 3      0.369863   0.333333   1.000000     0.600000       0.333333    0.461538
# 4      0.232877   0.333333   0.000000     0.333333       0.666667    0.538462
# ...         ...        ...        ...          ...            ...         ...
# 15055  0.219178   0.333333   0.600000     0.800000       0.666667    0.692308
# 15056  0.301370   0.333333   0.600000     0.800000       0.000000    0.692308
# 15057  0.287671   0.333333   0.600000     0.800000       0.333333    0.692308
# 15058  0.369863   0.333333   0.600000     0.800000       0.000000    0.000000
# 15059  0.246575   0.500000   0.600000     0.800000       0.333333    0.230769
#
# ...

# %% [markdown]
# ### Model Building

# %%
x_train=salary_train_scaled.drop('Salary',axis=1)
y_train=salary_train_scaled[['Salary']]

# %%
x_test=salary_test_scaled.drop('Salary',axis=1)
y_test=salary_test_scaled[['Salary']]

# %% [markdown]
# ### Model Training | Testing | Evaluation

# %% [markdown]
# #### Using Gaussian Naive Bayes

# %%
classifier=GaussianNB()
classifier.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print('Accuracy Score:',accuracy_score(y_test,y_pred))
print('Classification report :\n',classification_report(y_test,y_pred))
print('Confusion Matrix :\n',confusion_matrix(y_test,y_pred))
# Out:
# Accuracy Score: 0.796812749003984
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.81      0.95      0.88     11360
#          1.0       0.67      0.34      0.45      3700
#
#     accuracy                           0.80     15060
#    macro avg       0.74      0.64      0.66     15060
# weighted avg       0.78      0.80      0.77     15060
#
# Confusion Matrix :
#  [[10746   614]
#  [ 2446  1254]]

# %%
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# #### Using Multinomial Naive Bayes

# %%
classifier=MultinomialNB()
classifier.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print('Accuracy Score:',accuracy_score(y_test,y_pred))
print('Classification report :\n',classification_report(y_test,y_pred))
print('Confusion Matrix :\n',confusion_matrix(y_test,y_pred))
# Out:
# Accuracy Score: 0.7596945551128818
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.76      1.00      0.86     11360
#          1.0       0.96      0.02      0.04      3700
#
#     accuracy                           0.76     15060
#    macro avg       0.86      0.51      0.45     15060
# weighted avg       0.81      0.76      0.66     15060
#
# Confusion Matrix :
#  [[11356     4]
#  [ 3615    85]]

# %%
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
plt.show()
